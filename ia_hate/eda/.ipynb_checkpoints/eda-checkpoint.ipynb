# %%
import pandas as pd
import os
import seaborn as sns
import numpy as np 
import emoji

# %%
import spacy
nlp = spacy.load("es_core_news_lg")

# %%
os.listdir()
# Out:
# ['eda.ipynb', '.ipynb_checkpoints']

# %%
data_loc = "../master_data/DATA.csv"
df = pd.read_csv(data_loc)

# %%
df.shape
# Out:
# (11717, 4)

# %%
df.head()
# Out:
#      feature  label  tweet_id origin
# 0   es sexy.      1       NaN    rnn
# 1  eres mía.      1       NaN    rnn
# 2  la gorda.      1       NaN    rnn
# 3  a fregar.      1       NaN    rnn
# 4  ca- gona.      1       NaN    rnn

# %% [markdown]
# Cleaning
#
# * all text to lower caps
# * trim start,end whitespace
# * remove dot at sentence end.
# * remove \n literals
# * remove unbalanced " quotes
# * substitute q for "que"
# * substitute d for "de"
# * label for class misogino 1 no misogino 0
# * label wether it contains url
# * spacy tokenize

# %%
df.loc[:,["feature"]] = df.feature.str.lower()
df.loc[:,["feature"]] = df.feature.str.replace("\.$","",regex=True).\
str.replace("[\\n]+"," ",regex=True).\
str.replace("\"","").\
str.replace("\s*q ","que ",regex=True).\
str.replace(" d ","de").\
str.strip()
df.loc[:,["clase"]] = df.label.apply(lambda x: "misogino" if x == 1 else "no misogino")
df["has_image"] = df.feature.str.contains("http")
df.loc[:,["tokenized"]] = df.feature.apply(lambda x: [token for token in nlp(x)])

# %% [markdown]
# The following functions retrieve
# 1. clean word count
# 2. clean tokens
# * remove urls
# * remove nums
# * remove oov
# * remove digits
# * remove punctuation

# %%
def get_token_word_count(token_list):
    """
    gets tokens word_counts
    """
    
    count = 0
    for token in token_list:
        not_word = token.like_url or token.like_num or token.is_oov or token.is_digit or token.is_punct
        if not_word:
            continue
        else:
            count+=1
    return count

def clean_tokens(token_list):
    """
    cleans tokens
    """
    
    return [token for token in token_list if not (token.like_url or token.like_num or token.is_oov or token.is_digit or token.is_punct)]

def char_is_emoji(character):
    return character in emoji.EMOJI_DATA


def text_has_emoji(text):
    for character in text:
        if character in emoji.EMOJI_DATA:
            return True
    return False

def find_ngrams(input_list, n):
    grams = [i for i in zip(*[input_list[i:] for i in range(n)])]
    return Counter(grams)

# %%
df["word_count"] =df.tokenized.apply(get_token_word_count)
df["clean_tokens"] = df.tokenized.apply(clean_tokens)

# %%
df.head()
# Out:
#     feature  label  tweet_id origin     clase  has_image    tokenized  \
# 0   es sexy      1       NaN    rnn  misogino      False   [es, sexy]
# 1  eres mía      1       NaN    rnn  misogino      False  [eres, mía]
# 2  la gorda      1       NaN    rnn  misogino      False  [la, gorda]
# 3  a fregar      1       NaN    rnn  misogino      False  [a, fregar]
# 4  ca- gona      1       NaN    rnn  misogino      False  [ca-, gona]
#
#    word_count clean_tokens
# 0           2   [es, sexy]
# 1           2  [eres, mía]
# 2           2  [la, gorda]
# 3           2  [a, fregar]
# 4           2  [ca-, gona]

# %%
df.clase.value_counts().to_frame()
# Out:
#              count
# clase
# misogino      8689
# no misogino   3028

# %% [markdown]
# Histograma con la distribución del numero de palabras por feature.

# %%
sns.histplot(data=df, x="word_count")
# Out:
# <Axes: xlabel='word_count', ylabel='Count'>

# %% [markdown]
# Veamos la distribución separando por clases.
# En la gráfica inferior se puede observar que el número de palabras en el cuerpo
# de texto no es una característica que distinga un texto misógino de uno no misógino.
# Asimismo, se confirma que la muestra de datos no esta balanceada, pues hay más datos
# misóginos que no misóginos.

# %%
sns.histplot(data=df, x="word_count",hue="clase")
# Out:
# <Axes: xlabel='word_count', ylabel='Count'>

# %% [markdown]
# Analyzing most frquent words

# %%
# corpus = [word.text for i in sentences for word in i if not word.is_stop and not word.is_oov]

# %%
from collections import defaultdict, Counter
sentences = df.clean_tokens.values.tolist()
corpus_tokens = [token for i in sentences for token in i if not token.is_stop and not token.is_oov and not text_has_emoji(token.text)]
# create tokendict token_Text -> token
token_dict = {token.text:token for token in set(corpus_tokens)}
# create the corpus 
corpus = list(map(lambda token: token.text, corpus_tokens))
# # corpus = [text for text,token in corpus_tokens.items()]
count_dict=Counter(corpus)
# # create dataframe with count_dict
freq_df = pd.DataFrame.from_dict(count_dict,orient='index').reset_index(names=["word"])
freq_df.columns = ["word","freq"]
most_freq_emoji = freq_df.sort_values("freq",ascending=False).head(60)
#filter out emoji
most_freq = freq_df.loc[np.logical_not(freq_df.word.apply(text_has_emoji))].sort_values("freq",ascending=False)
most_freq.head(20)
# Out:
#            word  freq
# 18        mujer  1238
# 27         puta   786
# 54      mujeres   775
# 3081   feminazi   596
# 3312  feminazis   541
# 107      hombre   483
# 8466   arandina   453
# 153     hombres   411
# 763        años   367
# 570        vida   328
# 20         loca   282
# 618       mundo   238
# 1663       caso   228
# 310   feminismo   207
# 2        fregar   207
# 6528   patética   203
# 733   feminista   203
# 305       cosas   202
# 25         casa   193
# 2987      gente   179

# %% [markdown]
# Gráfica de barras con las palabras más usadas

# %%
sns.barplot(data= most_freq.head(30),x="freq",y="word")
# Out:
# <Axes: xlabel='freq', ylabel='word'>

# %%
bigrams_df = pd.DataFrame.from_dict(find_ngrams(corpus,2), orient='index').reset_index().rename(columns={"index":"bigram",0:"freq"})
bigrams_df\
.loc[bigrams_df.bigram.apply(lambda x: False if "arandina" in x else True)]\
.sort_values("freq",ascending=False).head(20)
# Out:
#                     bigram  freq
# 33819         (puta, idea)    67
# 64            (hija, puta)    58
# 94           (puta, madre)    55
# 25968       (años, cárcel)    42
# 46            (hijo, puta)    41
# 396         (mujer, mujer)    39
# 31549      (cumbre, clima)    35
# 1158       (hombre, mujer)    32
# 33571        (hijos, puta)    31
# 25990               (🇪, 🇸)    31
# 26416  (cambio, climático)    30
# 47428    (audios, víctima)    29
# 32097      (cállate, puta)    29
# 66         (pinche, vieja)    29
# 40756   (agresión, sexual)    29
# 25934       (puta, mierda)    29
# 30388               (️, ️)    28
# 44334    (sentencia, caso)    27
# 29361  (derechos, humanos)    26
# 33901         (puta, vida)    25

# %%
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 64154    False
# 64155     True
# 64156     True
# 64157    False
# 64158     True
# Name: bigram, Length: 64159, dtype: bool

# %%
trigrams_df = pd.DataFrame.from_dict(find_ngrams(corpus,3), orient='index').reset_index().rename(columns={"index":"trigram",0:"freq"})
trigrams_df\
.loc[trigrams_df.trigram.apply(lambda x: False if "arandina" in x else True)]\
.sort_values("freq",ascending=False).head(20)
# Out:
#                                 trigram  freq
# 28184                         (🇪, 🇸, 🇪)    24
# 28185                         (🇸, 🇪, 🇸)    24
# 37331              (tienes, puta, idea)    23
# 30402                         (🇦, 🇷, 🇦)    18
# 30403                         (🇷, 🇦, 🇷)    18
# 1551                 (gusta, den, duro)    17
# 32803                         (️, ️, ️)    14
# 51041         (agresión, sexual, menor)    12
# 10662       (pinche, vieja, interesada)    12
# 10517         (encanta, panocha, tetas)    11
# 44336              (año, revista, time)    11
# 10237             (doy, paliza, escapo)    10
# 60185           (cumbre, clima, madrid)     9
# 64536  (violaciones, derechos, humanos)     9
# 10411              (pa, hacerte, venir)     8
# 34205           (persona, año, revista)     8
# 51613       (difusión, audios, víctima)     8
# 7714            (quiero, chingan, digo)     7
# 51525           (audios, víctima, caso)     7
# 51870       (difundir, audios, víctima)     7

# %% [markdown]
# WordCloud

# %%
# !pip install wordcloud
# Out:
# Looking in indexes: https://gcp-data-platform-ro:****@pypi-dot-etsy-batchjobs-prod-dot-us-central1.etsycloud.com/simple
# Requirement already satisfied: wordcloud in /Users/fbahena/.pyenv/versions/3.9.16/envs/nlpenv/lib/python3.9/site-packages (1.9.3)
# Requirement already satisfied: numpy>=1.6.1 in /Users/fbahena/.pyenv/versions/3.9.16/envs/nlpenv/lib/python3.9/site-packages (from wordcloud) (1.26.0)
# Requirement already satisfied: pillow in /Users/fbahena/.pyenv/versions/3.9.16/envs/nlpenv/lib/python3.9/site-packages (from wordcloud) (10.1.0)
# Requirement already satisfied: matplotlib in /Users/fbahena/.pyenv/versions/3.9.16/envs/nlpenv/lib/python3.9/site-packages (from wordcloud) (3.8.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/fbahena/.pyenv/versions/3.9.16/envs/nlpenv/lib/python3.9/site-packages (from matplotlib->wordcloud) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /Users/fbahena/.pyenv/versions/3.9.16/envs/nlpenv/lib/python3.9/site-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/fbahena/.pyenv/versions/3.9.16/envs/nlpenv/lib/python3.9/site-packages (from matplotlib->wordcloud) (4.44.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/fbahena/.pyenv/versions/3.9.16/envs/nlpenv/lib/python3.9/site-packages (from matplotlib->wordcloud) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /Users/fbahena/.pyenv/versions/3.9.16/envs/nlpenv/lib/python3.9/site-packages (from matplotlib->wordcloud) (23.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/fbahena/.pyenv/versions/3.9.16/envs/nlpenv/lib/python3.9/site-packages (from matplotlib->wordcloud) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/fbahena/.pyenv/versions/3.9.16/envs/nlpenv/lib/python3.9/site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/fbahena/.pyenv/versions/3.9.16/envs/nlpenv/lib/python3.9/site-packages (from matplotlib->wordcloud) (6.1.1)
# Requirement already satisfied: zipp>=3.1.0 in /Users/fbahena/.pyenv/versions/3.9.16/envs/nlpenv/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib->wordcloud) (3.17.0)
# Requirement already satisfied: six>=1.5 in /Users/fbahena/.pyenv/versions/3.9.16/envs/nlpenv/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
#
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: pip install --upgrade pip

# %%
# Out:
# 'sexy gorda fregar ca- gona bruja vieja golfa víbora maruja'

# %%
from wordcloud import WordCloud

# Read the whole text.
text = " ".join(corpus)

# Generate a word cloud image
wordcloud = WordCloud().generate(text)

# Display the generated image:
# the matplotlib way:
import matplotlib.pyplot as plt


# take relative word frequencies into account, lower max_font_size
wordcloud = WordCloud(background_color="white",max_words=len(text),max_font_size=40, relative_scaling=.5).generate(text)
plt.figure()
plt.imshow(wordcloud)
plt.axis("off")
plt.show()
